# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/DeepLabCut/DeepLabCut/blob/main/examples/COLAB/COLAB_DEMO_SuperAnimal.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # First, go to "Runtime" ->"change runtime type"->select "Python3", and then select "GPU"

# %%
# !pip install "deeplabcut[tf,modelzoo] @ git+https://github.com/DeepLabCut/DeepLabCut@main"
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main
#   Cloning https://github.com/DeepLabCut/DeepLabCut (to revision main) to /tmp/pip-install-xdl_999h/deeplabcut_362062b6d89b4bc98aa87fb5e069899a
#   Running command git clone --filter=blob:none --quiet https://github.com/DeepLabCut/DeepLabCut /tmp/pip-install-xdl_999h/deeplabcut_362062b6d89b4bc98aa87fb5e069899a
#   Resolved https://github.com/DeepLabCut/DeepLabCut to commit ba171959cc53a50d6ac4a51aa5dba42df621936e
#   Preparing metadata (setup.py) ... done
# Collecting dlclibrary (from deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main)
#   Downloading dlclibrary-0.0.3-py3-none-any.whl (14 kB)
# Collecting filterpy>=1.4.4 (from deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main)
#   Downloading filterpy-1.4.5.zip (177 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.0/178.0 kB 4.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting ruamel.yaml>=0.15.0 (from deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main)
#   Downloading ruamel.yaml-0.17.26-py3-none-any.whl (109 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.1/109.1 kB 396.7 kB/s eta 0:00:00
# Requirement already satisfied: imgaug>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main) (0.4.0)
# Requirement already satisfied: imageio-ffmpeg in /usr/local/lib/python3.10/dist-packages (from deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main) (0.4.8)
# Requirement already satisfied: numba>=0.54 in /usr/local/lib/python3.10/dist-packages (from deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main) (0.56.4)
# Requirement already satisfied: matplotlib>=3.3 in /usr/local/lib/python3.10/dist-packages (from deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main) (3.7.1)
# Requirement already satisfied: networkx>=2.6 in /usr/local/lib/python3.10/dist-packages (from deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main) (3.1)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main) (1.22.4)
# Requirement already satisfied: pandas!=1.5.0,>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main) (1.5.3)
# Requirement already satisfied: scikit-image>=0.17 in /usr/local/lib/python3.10/dist-packages (from deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main) (0.19.3)
# Requirement already satisfied: scikit-learn>=1.0 in /usr/local/lib/python3.10/dist-packages (from deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main) (1.2.2)
# Requirement already satisfied: scipy>=1.4 in /usr/local/lib/python3.10/dist-packages (from deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main) (1.10.1)
# Requirement already satisfied: statsmodels>=0.11 in /usr/local/lib/python3.10/dist-packages (from deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main) (0.13.5)
# Requirement already satisfied: tables>=3.7.0 in /usr/local/lib/python3.10/dist-packages (from deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main) (3.8.0)
# Collecting torch<=1.12 (from deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main)
#   Downloading torch-1.12.0-cp310-cp310-manylinux1_x86_64.whl (776.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 776.3/776.3 MB 2.2 MB/s eta 0:00:00
# Collecting tensorpack>=0.11 (from deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main)
#   Downloading tensorpack-0.11-py2.py3-none-any.whl (296 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.3/296.3 kB 36.4 MB/s eta 0:00:00
# Requirement already satisfied: tf_slim>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main) (1.1.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main) (4.65.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main) (6.0)
# Requirement already satisfied: Pillow>=7.1 in /usr/local/lib/python3.10/dist-packages (from deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main) (8.4.0)
# Collecting tensorflow<=2.10,>=2.0 (from deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main)
#   Downloading tensorflow-2.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (578.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 578.0/578.0 MB 2.2 MB/s eta 0:00:00
# Collecting huggingface_hub (from deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main)
#   Downloading huggingface_hub-0.14.1-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 26.3 MB/s eta 0:00:00
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from imgaug>=0.4.0->deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main) (1.16.0)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from imgaug>=0.4.0->deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main) (4.7.0.72)
# Requirement already satisfied: imageio in /usr/local/lib/python3.10/dist-packages (from imgaug>=0.4.0->deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main) (2.25.1)
# Requirement already satisfied: Shapely in /usr/local/lib/python3.10/dist-packages (from imgaug>=0.4.0->deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main) (2.0.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main) (2.8.2)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.54->deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from numba>=0.54->deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main) (67.7.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas!=1.5.0,>=1.0.1->deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main) (2022.7.1)
# Collecting ruamel.yaml.clib>=0.2.7 (from ruamel.yaml>=0.15.0->deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main)
#   Downloading ruamel.yaml.clib-0.2.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (485 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.6/485.6 kB 47.6 MB/s eta 0:00:00
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.17->deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main) (2023.4.12)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.17->deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main) (1.4.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0->deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0->deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main) (3.1.0)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.10/dist-packages (from statsmodels>=0.11->deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main) (0.5.3)
# Requirement already satisfied: cython>=0.29.21 in /usr/local/lib/python3.10/dist-packages (from tables>=3.7.0->deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main) (0.29.34)
# Requirement already satisfied: numexpr>=2.6.2 in /usr/local/lib/python3.10/dist-packages (from tables>=3.7.0->deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main) (2.8.4)
# Requirement already satisfied: blosc2~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from tables>=3.7.0->deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main) (2.0.0)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from tables>=3.7.0->deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main) (9.0.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<=2.10,>=2.0->deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<=2.10,>=2.0->deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<=2.10,>=2.0->deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main) (23.3.3)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<=2.10,>=2.0->deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<=2.10,>=2.0->deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow<=2.10,>=2.0->deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main) (1.54.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<=2.10,>=2.0->deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main) (3.8.0)
# Collecting keras<2.11,>=2.10.0 (from tensorflow<=2.10,>=2.0->deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main)
#   Downloading keras-2.10.0-py2.py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 86.6 MB/s eta 0:00:00
# Collecting keras-preprocessing>=1.1.1 (from tensorflow<=2.10,>=2.0->deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main)
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 5.2 MB/s eta 0:00:00
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<=2.10,>=2.0->deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main) (16.0.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow<=2.10,>=2.0->deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main) (3.3.0)
# Collecting protobuf<3.20,>=3.9.2 (from tensorflow<=2.10,>=2.0->deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main)
#   Downloading protobuf-3.19.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 63.6 MB/s eta 0:00:00
# Collecting tensorboard<2.11,>=2.10 (from tensorflow<=2.10,>=2.0->deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main)
#   Downloading tensorboard-2.10.1-py3-none-any.whl (5.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 105.0 MB/s eta 0:00:00
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<=2.10,>=2.0->deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main) (0.32.0)
# Collecting tensorflow-estimator<2.11,>=2.10.0 (from tensorflow<=2.10,>=2.0->deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main)
#   Downloading tensorflow_estimator-2.10.0-py2.py3-none-any.whl (438 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 438.7/438.7 kB 44.9 MB/s eta 0:00:00
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<=2.10,>=2.0->deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow<=2.10,>=2.0->deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main) (4.5.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<=2.10,>=2.0->deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main) (1.14.1)
# Requirement already satisfied: tabulate>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from tensorpack>=0.11->deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main) (0.8.10)
# Requirement already satisfied: msgpack>=0.5.2 in /usr/local/lib/python3.10/dist-packages (from tensorpack>=0.11->deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main) (1.0.5)
# Collecting msgpack-numpy>=0.4.4.2 (from tensorpack>=0.11->deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main)
#   Downloading msgpack_numpy-0.4.8-py2.py3-none-any.whl (6.9 kB)
# Requirement already satisfied: pyzmq>=16 in /usr/local/lib/python3.10/dist-packages (from tensorpack>=0.11->deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main) (23.2.1)
# Requirement already satisfied: psutil>=5 in /usr/local/lib/python3.10/dist-packages (from tensorpack>=0.11->deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main) (5.9.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main) (3.12.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main) (2023.4.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main) (2.27.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow<=2.10,>=2.0->deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main) (0.40.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.11,>=2.10->tensorflow<=2.10,>=2.0->deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main) (2.17.3)
# Collecting google-auth-oauthlib<0.5,>=0.4.1 (from tensorboard<2.11,>=2.10->tensorflow<=2.10,>=2.0->deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main)
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.11,>=2.10->tensorflow<=2.10,>=2.0->deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main) (3.4.3)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0 (from tensorboard<2.11,>=2.10->tensorflow<=2.10,>=2.0->deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main)
#   Downloading tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 107.8 MB/s eta 0:00:00
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.11,>=2.10->tensorflow<=2.10,>=2.0->deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.11,>=2.10->tensorflow<=2.10,>=2.0->deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main) (2.3.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub->deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub->deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub->deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub->deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main) (3.4)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow<=2.10,>=2.0->deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow<=2.10,>=2.0->deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow<=2.10,>=2.0->deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow<=2.10,>=2.0->deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.11,>=2.10->tensorflow<=2.10,>=2.0->deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main) (2.1.2)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow<=2.10,>=2.0->deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow<=2.10,>=2.0->deeplabcut[modelzoo,tf]@ git+https://github.com/DeepLabCut/DeepLabCut@main) (3.2.2)
# Building wheels for collected packages: filterpy, deeplabcut
#   Building wheel for filterpy (setup.py) ... done
#   Created wheel for filterpy: filename=filterpy-1.4.5-py3-none-any.whl size=110459 sha256=d6fcc38d97eeae1cb86b0f626c82242f440722209db99a5edf90f7909c295e59
#   Stored in directory: /root/.cache/pip/wheels/0f/0c/ea/218f266af4ad626897562199fbbcba521b8497303200186102
#   Building wheel for deeplabcut (setup.py) ... done
#   Created wheel for deeplabcut: filename=deeplabcut-2.3.4-py3-none-any.whl size=1380653 sha256=79df274219fddb55f21719c5b92c83595b2b5b9af7cd31eed488cb255d748d8a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-4pcmd7n8/wheels/63/89/98/91f257cf4a6f22b1931c24a1b39a204b354a0501188313c25a
# Successfully built filterpy deeplabcut
# Installing collected packages: keras, torch, tensorflow-estimator, tensorboard-data-server, ruamel.yaml.clib, protobuf, msgpack-numpy, keras-preprocessing, tensorpack, ruamel.yaml, huggingface_hub, google-auth-oauthlib, filterpy, dlclibrary, tensorboard, deeplabcut, tensorflow
#   Attempting uninstall: keras
#     Found existing installation: keras 2.12.0
#     Uninstalling keras-2.12.0:
#       Successfully uninstalled keras-2.12.0
#   Attempting uninstall: torch
#     Found existing installation: torch 2.0.0+cu118
#     Uninstalling torch-2.0.0+cu118:
#       Successfully uninstalled torch-2.0.0+cu118
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.12.0
#     Uninstalling tensorflow-estimator-2.12.0:
#       Successfully uninstalled tensorflow-estimator-2.12.0
#   Attempting uninstall: tensorboard-data-server
#     Found existing installation: tensorboard-data-server 0.7.0
#     Uninstalling tensorboard-data-server-0.7.0:
#       Successfully uninstalled tensorboard-data-server-0.7.0
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
#   Attempting uninstall: google-auth-oauthlib
#     Found existing installation: google-auth-oauthlib 1.0.0
#     Uninstalling google-auth-oauthlib-1.0.0:
#       Successfully uninstalled google-auth-oauthlib-1.0.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.12.2
#     Uninstalling tensorboard-2.12.2:
#       Successfully uninstalled tensorboard-2.12.2
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.12.0
#     Uninstalling tensorflow-2.12.0:
#       Successfully uninstalled tensorflow-2.12.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-datasets 4.9.2 requires protobuf>=3.20, but you have protobuf 3.19.6 which is incompatible.
# tensorflow-metadata 1.13.1 requires protobuf<5,>=3.20.3, but you have protobuf 3.19.6 which is incompatible.
# torchaudio 2.0.1+cu118 requires torch==2.0.0, but you have torch 1.12.0 which is incompatible.
# torchdata 0.6.0 requires torch==2.0.0, but you have torch 1.12.0 which is incompatible.
# torchtext 0.15.1 requires torch==2.0.0, but you have torch 1.12.0 which is incompatible.
# torchvision 0.15.1+cu118 requires torch==2.0.0, but you have torch 1.12.0 which is incompatible.
# Successfully installed deeplabcut-2.3.4 dlclibrary-0.0.3 filterpy-1.4.5 google-auth-oauthlib-0.4.6 huggingface_hub-0.14.1 keras-2.10.0 keras-preprocessing-1.1.2 msgpack-numpy-0.4.8 protobuf-3.19.6 ruamel.yaml-0.17.26 ruamel.yaml.clib-0.2.7 tensorboard-2.10.1 tensorboard-data-server-0.6.1 tensorflow-2.10.0 tensorflow-estimator-2.10.0 tensorpack-0.11 torch-1.12.0

# %% [markdown]
# ## PLEASE, click "restart runtime" from the output above before proceeding!

# %%
import deeplabcut
import os
# Out:
# Loading DLC 2.3.4...
# DLC loaded in light mode; you cannot use any GUI (labeling, relabeling and standalone GUI)

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %% [markdown]
# ### Constructing input-output directories

# %%
base_dir = '/gdrive/Shareddrives/Turi_lab/Data/Context_project'

# %%
context = 'Context2'
task = 'OFT'
condition = 'baseline'

# %%
f = os.path.join(base_dir, context, context +'_' + task, condition)
f
# Out:
# '/gdrive/Shareddrives/Turi_lab/Data/Context_project/Context2/Context2_OFT/baseline'

# %%
# the DLC input folder with videos

try:
  if os.path.isdir(os.path.join(base_dir, context, context +'_' + task, condition)):
    video_path = os.path.join(base_dir, context, context +'_' + task, condition)
    print('Directory exists')
  else:
    print('Directory does not exist')
except:
  print("An error occurred while checking the directory:", str(e))
# Out:
# Directory exists

# %%
# the output folder for the analyis

if not os.path.exists(os.path.join(base_dir, 'moseq_analysis', context + '_' + task, condition)):
  print('No working_directory. ... Creating working_directory')
  os.makedirs(os.path.join(base_dir, 'moseq_analysis', context + '_' + task, condition))
  working_directory = os.path.join(base_dir, 'moseq_analysis', context + '_' + task, condition)  
else:
  print('working_directory exist')
  working_directory = os.path.join(base_dir, 'moseq_analysis', context + '_' + task, condition)
# Out:
# working_directory exist

# %%
plot_directory
# Out:
# '/gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/plots'

# %%
working_directory = os.path.join(base_dir,'moseq_analysis', context + '_' + task, condition)
working_directory
# Out:
# '/gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline'

# %%
# the DLC config.yml file will be populated with these
project_name = 'modelzoo_analysis' 
your_name = 'gergo'

# %%
# use working_directory argument to specify where the project will be created.
# this cell will take all the videos in the `video_path` folder and make a copy
# in the `working_directory` folder. 
config_path, train_config_path = deeplabcut.create_pretrained_project(
    project_name,
    your_name,    
    [video_path],
    working_directory = working_directory,
    videotype=".avi",
    model="superanimal_topviewmouse",
    analyzevideo=True,
    createlabeledvideo=False, # will be created further down in this notebook
    copy_videos=True, #must leave copy_videos=True
)
# Out:
# Created "/gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos"
# Created "/gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/labeled-data"
# Created "/gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/training-datasets"
# Created "/gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/dlc-models"
# 20  videos from the directory /gdrive/Shareddrives/Turi_lab/Data/Context_project/Context2/Context2_OFT/baseline were added to the project.
# Copying the videos
# /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos/Context2_OFT_baseline_01.avi
# /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos/Context2_OFT_baseline_71.avi
# /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos/Context2_OFT_baseline_81.avi
# /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos/Context2_OFT_baseline_91.avi
# /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos/Context2_OFT_baseline_02.avi
# /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos/Context2_OFT_baseline_72.avi
# /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos/Context2_OFT_baseline_82.avi
# /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos/Context2_OFT_baseline_92.avi
# /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos/Context2_OFT_baseline_03.avi
# /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos/Context2_OFT_baseline_73.avi
# /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos/Context2_OFT_baseline_83.avi
# /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos/Context2_OFT_baseline_93.avi
# /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos/Context2_OFT_baseline_04.avi
# /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos/Context2_OFT_baseline_74.avi
# /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos/Context2_OFT_baseline_84.avi
# /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos/Context2_OFT_baseline_94.avi
# /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos/Context2_OFT_baseline_05.avi
# /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos/Context2_OFT_baseline_75.avi
# /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos/Context2_OFT_baseline_85.avi
# /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos/Context2_OFT_baseline_95.avi
# Generated "/gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/config.yaml"
#
# A new project with name modelzoo_analysis-gergo-2023-05-16 is created at /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline and a configurable file (config.yaml) is stored there. Change the parameters in this file to adapt to your project's needs.
#  Once you have changed the configuration file, use the function 'extract_frames' to select frames for labeling.
# . [OPTIONAL] Use the function 'add_new_videos' to add new videos to your project (at any stage).
# Downloading weights...
# Loading.... superanimal_topviewmouse
# Downloading (…)n-0_shuffle-1.tar.gz:   0%|          | 0.00/235M [00:00<?, ?B/s]
# /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/dlc-models/iteration-0/modelzoo_analysisMay16-trainset95shuffle1/train/pose_cfg.yaml
# Analyzing video...
# Using snapshot-200000 for model /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/dlc-models/iteration-0/modelzoo_analysisMay16-trainset95shuffle1
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/keras/engine/base_layer_v1.py:1694: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   warnings.warn('`layer.apply` is deprecated and '
# Analyzing all the videos in the directory...
# Starting to analyze %  /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos/Context2_OFT_baseline_84.avi
# Loading  /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos/Context2_OFT_baseline_84.avi
# Duration of video [s]:  667.17 , recorded with  12.0 fps!
# Overall # of frames:  8006  found with (before cropping) frame dimensions:  480 480
# Starting to extract posture
# 100%|██████████| 8006/8006 [01:16<00:00, 104.63it/s]
# Saving results in /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos...
# Saving csv poses!
# Starting to analyze %  /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos/Context2_OFT_baseline_01.avi
# Loading  /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos/Context2_OFT_baseline_01.avi
# Duration of video [s]:  1016.38 , recorded with  8.0 fps!
# Overall # of frames:  8131  found with (before cropping) frame dimensions:  480 480
# Starting to extract posture
# 100%|██████████| 8131/8131 [01:02<00:00, 130.34it/s]
# Saving results in /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos...
# Saving csv poses!
# Starting to analyze %  /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos/Context2_OFT_baseline_85.avi
# Loading  /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos/Context2_OFT_baseline_85.avi
# Duration of video [s]:  659.5 , recorded with  12.0 fps!
# Overall # of frames:  7914  found with (before cropping) frame dimensions:  480 480
# Starting to extract posture
# 100%|██████████| 7914/7914 [01:05<00:00, 120.14it/s]
# Saving results in /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos...
# Saving csv poses!
# Starting to analyze %  /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos/Context2_OFT_baseline_02.avi
# Loading  /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos/Context2_OFT_baseline_02.avi
# Duration of video [s]:  717.27 , recorded with  11.0 fps!
# Overall # of frames:  7890  found with (before cropping) frame dimensions:  480 480
# Starting to extract posture
# 100%|██████████| 7890/7890 [01:05<00:00, 121.18it/s]
# Saving results in /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos...
# Saving csv poses!
# Starting to analyze %  /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos/Context2_OFT_baseline_81.avi
# Loading  /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos/Context2_OFT_baseline_81.avi
# Duration of video [s]:  1015.62 , recorded with  8.0 fps!
# Overall # of frames:  8125  found with (before cropping) frame dimensions:  480 480
# Starting to extract posture
# 100%|██████████| 8125/8125 [01:07<00:00, 120.58it/s]
# Saving results in /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos...
# Saving csv poses!
# Starting to analyze %  /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos/Context2_OFT_baseline_82.avi
# Loading  /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos/Context2_OFT_baseline_82.avi
# Duration of video [s]:  655.83 , recorded with  12.0 fps!
# Overall # of frames:  7870  found with (before cropping) frame dimensions:  480 480
# Starting to extract posture
# 100%|██████████| 7870/7870 [01:05<00:00, 120.89it/s]
# Saving results in /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos...
# Saving csv poses!
# Starting to analyze %  /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos/Context2_OFT_baseline_92.avi
# Loading  /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos/Context2_OFT_baseline_92.avi
# Duration of video [s]:  604.31 , recorded with  13.0 fps!
# Overall # of frames:  7856  found with (before cropping) frame dimensions:  480 480
# Starting to extract posture
# 100%|██████████| 7856/7856 [01:04<00:00, 120.92it/s]
# Saving results in /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos...
# Saving csv poses!
# Starting to analyze %  /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos/Context2_OFT_baseline_93.avi
# Loading  /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos/Context2_OFT_baseline_93.avi
# Duration of video [s]:  626.23 , recorded with  13.0 fps!
# Overall # of frames:  8141  found with (before cropping) frame dimensions:  480 480
# Starting to extract posture
# 100%|██████████| 8141/8141 [01:07<00:00, 120.56it/s]
# Saving results in /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos...
# Saving csv poses!
# Starting to analyze %  /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos/Context2_OFT_baseline_05.avi
# Loading  /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos/Context2_OFT_baseline_05.avi
# Duration of video [s]:  719.27 , recorded with  11.0 fps!
# Overall # of frames:  7912  found with (before cropping) frame dimensions:  480 480
# Starting to extract posture
# 100%|██████████| 7912/7912 [01:00<00:00, 131.57it/s]
# Saving results in /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos...
# Saving csv poses!
# Starting to analyze %  /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos/Context2_OFT_baseline_04.avi
# Loading  /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos/Context2_OFT_baseline_04.avi
# Duration of video [s]:  801.8 , recorded with  10.0 fps!
# Overall # of frames:  8018  found with (before cropping) frame dimensions:  480 480
# Starting to extract posture
# 100%|██████████| 8018/8018 [01:01<00:00, 130.61it/s]
# Saving results in /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos...
# Saving csv poses!
# Starting to analyze %  /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos/Context2_OFT_baseline_94.avi
# Loading  /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos/Context2_OFT_baseline_94.avi
# Duration of video [s]:  669.25 , recorded with  12.0 fps!
# Overall # of frames:  8031  found with (before cropping) frame dimensions:  480 480
# Starting to extract posture
# 100%|██████████| 8031/8031 [01:01<00:00, 130.72it/s]
# Saving results in /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos...
# Saving csv poses!
# Starting to analyze %  /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos/Context2_OFT_baseline_91.avi
# Loading  /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos/Context2_OFT_baseline_91.avi
# Duration of video [s]:  811.9 , recorded with  10.0 fps!
# Overall # of frames:  8119  found with (before cropping) frame dimensions:  480 480
# Starting to extract posture
# 100%|██████████| 8119/8119 [01:02<00:00, 129.85it/s]
# Saving results in /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos...
# Saving csv poses!
# Starting to analyze %  /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos/Context2_OFT_baseline_95.avi
# Loading  /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos/Context2_OFT_baseline_95.avi
# Duration of video [s]:  658.58 , recorded with  12.0 fps!
# Overall # of frames:  7903  found with (before cropping) frame dimensions:  480 480
# Starting to extract posture
# 100%|██████████| 7903/7903 [01:00<00:00, 131.45it/s]
# Saving results in /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos...
# Saving csv poses!
# Starting to analyze %  /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos/Context2_OFT_baseline_75.avi
# Loading  /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos/Context2_OFT_baseline_75.avi
# Duration of video [s]:  719.27 , recorded with  11.0 fps!
# Overall # of frames:  7912  found with (before cropping) frame dimensions:  480 480
# Starting to extract posture
# 100%|██████████| 7912/7912 [01:05<00:00, 121.16it/s]
# Saving results in /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos...
# Saving csv poses!
# Starting to analyze %  /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos/Context2_OFT_baseline_03.avi
# Loading  /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos/Context2_OFT_baseline_03.avi
# Duration of video [s]:  741.0 , recorded with  11.0 fps!
# Overall # of frames:  8151  found with (before cropping) frame dimensions:  480 480
# Starting to extract posture
# 100%|██████████| 8151/8151 [01:01<00:00, 131.64it/s]
# Saving results in /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos...
# Saving csv poses!
# Starting to analyze %  /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos/Context2_OFT_baseline_73.avi
# Loading  /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos/Context2_OFT_baseline_73.avi
# Duration of video [s]:  741.73 , recorded with  11.0 fps!
# Overall # of frames:  8159  found with (before cropping) frame dimensions:  480 480
# Starting to extract posture
# 100%|██████████| 8159/8159 [01:02<00:00, 131.12it/s]
# Saving results in /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos...
# Saving csv poses!
# Starting to analyze %  /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos/Context2_OFT_baseline_83.avi
# Loading  /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos/Context2_OFT_baseline_83.avi
# Duration of video [s]:  679.25 , recorded with  12.0 fps!
# Overall # of frames:  8151  found with (before cropping) frame dimensions:  480 480
# Starting to extract posture
# 100%|██████████| 8151/8151 [01:02<00:00, 130.69it/s]
# Saving results in /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos...
# Saving csv poses!
# Starting to analyze %  /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos/Context2_OFT_baseline_71.avi
# Loading  /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos/Context2_OFT_baseline_71.avi
# Duration of video [s]:  1016.38 , recorded with  8.0 fps!
# Overall # of frames:  8131  found with (before cropping) frame dimensions:  480 480
# Starting to extract posture
# 100%|██████████| 8131/8131 [01:02<00:00, 129.89it/s]
# Saving results in /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos...
# Saving csv poses!
# Starting to analyze %  /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos/Context2_OFT_baseline_72.avi
# Loading  /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos/Context2_OFT_baseline_72.avi
# Duration of video [s]:  715.54 , recorded with  11.0 fps!
# Overall # of frames:  7871  found with (before cropping) frame dimensions:  480 480
# Starting to extract posture
# 100%|██████████| 7871/7871 [01:00<00:00, 129.41it/s]
# Saving results in /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos...
# Saving csv poses!
# Starting to analyze %  /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos/Context2_OFT_baseline_74.avi
# Loading  /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos/Context2_OFT_baseline_74.avi
# Duration of video [s]:  667.08 , recorded with  12.0 fps!
# Overall # of frames:  8005  found with (before cropping) frame dimensions:  480 480
# Starting to extract posture
# 100%|██████████| 8005/8005 [01:01<00:00, 130.77it/s]
# Saving results in /gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos...
# Saving csv poses!
# The videos are analyzed. Now your research can truly start!
#  You can create labeled videos with 'create_labeled_video'
# If the tracking is not satisfactory for some videos, consider expanding the training set. You can use the function 'extract_outlier_frames' to extract a few representative outlier frames.

# %% [markdown]
# ### update the skeleton section in the new dlc yconfig.yml file!

# %%
# Updating the plotting within the config.yaml file (without opening it ;):
edits = {
    'dotsize': 3,  # size of the dots!
    'colormap': 'spring',  # any matplotlib colormap!
    'pcutoff': 0.7,  # the higher the more conservative the plotting!
}
deeplabcut.auxiliaryfunctions.edit_config(config_path, edits)
# Out:
# {'Task': 'modelzoo_analysis', 'scorer': 'gergo', 'date': 'May16', 'multianimalproject': False, 'identity': None, 'project_path': '/gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16', 'video_sets': {'/gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos/Context2_OFT_baseline_01.avi': {'crop': '0, 480, 0, 480'}, '/gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos/Context2_OFT_baseline_71.avi': {'crop': '0, 480, 0, 480'}, '/gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos/Context2_OFT_baseline_81.avi': {'crop': '0, 480, 0, 480'}, '/gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos/Context2_OFT_baseline_91.avi': {'crop': '0, 480, 0, 480'}, '/gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos/Context2_OFT_baseline_02.avi': {'crop': '0, 480, 0, 480'}, '/gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos/Context2_OFT_baseline_72.avi': {'crop': '0, 480, 0, 480'}, '/gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos/Context2_OFT_baseline_82.avi': {'crop': '0, 480, 0, 480'}, '/gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos/Context2_OFT_baseline_92.avi': {'crop': '0, 480, 0, 480'}, '/gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos/Context2_OFT_baseline_03.avi': {'crop': '0, 480, 0, 480'}, '/gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos/Context2_OFT_baseline_73.avi': {'crop': '0, 480, 0, 480'}, '/gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos/Context2_OFT_baseline_83.avi': {'crop': '0, 480, 0, 480'}, '/gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos/Context2_OFT_baseline_93.avi': {'crop': '0, 480, 0, 480'}, '/gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos/Context2_OFT_baseline_04.avi': {'crop': '0, 480, 0, 480'}, '/gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos/Context2_OFT_baseline_74.avi': {'crop': '0, 480, 0, 480'}, '/gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos/Context2_OFT_baseline_84.avi': {'crop': '0, 480, 0, 480'}, '/gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos/Context2_OFT_baseline_94.avi': {'crop': '0, 480, 0, 480'}, '/gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos/Context2_OFT_baseline_05.avi': {'crop': '0, 480, 0, 480'}, '/gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos/Context2_OFT_baseline_75.avi': {'crop': '0, 480, 0, 480'}, '/gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos/Context2_OFT_baseline_85.avi': {'crop': '0, 480, 0, 480'}, '/gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05 ...

# %%
# re-create the labeled video (first you will need to delete in the folder to the LEFT!):
project_path = os.path.dirname(config_path)
full_video_path = os.path.join(
    project_path,
    'videos',
    
) #os.path.basename(video_path),

#filter predictions (should already be done above ;):
deeplabcut.filterpredictions(config_path, [full_video_path], videotype='.avi')

#re-create the video with your edits!
deeplabcut.create_labeled_video(config_path, [full_video_path], videotype='.avi', filtered=True)

# %%
config_path
# Out:
# '/gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/config.yaml'

# %% [markdown]
# it seems to work up until this 👆
#
# can the raw `.avi` files removed at this point?

# %%
full_video_path
# Out:
# '/gdrive/Shareddrives/Turi_lab/Data/Context_project/moseq_analysis/Context2_OFT/baseline/modelzoo_analysis-gergo-2023-05-16/videos'

# %%
# this does not work
deeplabcut.plot_trajectories(config_path, full_video_path, videotype='avi', 
                             filtered=True, displayedbodyparts=['tail_base',
                                                                'mid_backend',
                                                                'mid_backend2',
                                                                'mid_backend3',
                                                                'head_midpoint',
                                                                'nose', 
                                                                'right_ear',
                                                                'left_ear',
                                                                'head_midpoint'
                                                                ],
                             destfolder=plot_path, resolution=300)
